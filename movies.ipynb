# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# top250_movies_india = pd.read_csv('data/IMDB_India_Top250.csv',index_col='Movie name')
top250_movies_india = pd.read_csv('data/IMDB_India_Top250.csv')
top250_movies_india.head()
top250_movies_india.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Movie name             250 non-null    object
#  1   Year of release        250 non-null    int64
#  2   Watch  hour            250 non-null    object
#  3   Rating                 250 non-null    float64
#  4   Ratedby                250 non-null    object
#  5   Film Industry          250 non-null    object
#  6   Genre                  250 non-null    object
#  7   Director               250 non-null    object
#  8   Box office collection  250 non-null    object
#  9   User reviews           250 non-null    int64
#  10  Awards                 250 non-null    object
#  11  Description            250 non-null    object
#  12  Streaming platform     250 non-null    object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 25.5+ KB

# %%
plt.figure(figsize=(30,130))
plt.title("Average Arrival Delay for Spirit Airlines Flights, by Month")
sns.barplot(y=top250_movies_india.index, x=top250_movies_india['Streaming platform'])
# plt.ylabel("Arrival delay (in minutes)")
# Out:
# <Axes: title={'center': 'Average Arrival Delay for Spirit Airlines Flights, by Month'}, xlabel='Streaming platform', ylabel='Movie name'>
