# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# top250_movies_india = pd.read_csv('data/IMDB_India_Top250.csv',index_col='Movie name')
top250_movies_india = pd.read_csv('data/IMDB_India_Top250.csv')
top250_movies_india.head()
# top250_movies_india.describe()
# top250_movies_india.columns
# Out:
#           MovieName  YearOfRelease          WatchHour   Rating Ratedby  \
# 0         12th Fail           2023  2 hours 27 minutes     8.9    126K
# 1          Gol Maal           1979            2 hours      8.5     20K
# 2          Maharaja           2024  2 hours 30 minutes     8.6     37K
# 3           Nayakan           1987  2 hours 25 minutes     8.7     25K
# 4  The World of Apu           1959   1 hour 45 minutes     8.4     17K
#
#         FilmIndustry             Genre              Director  \
# 0  Bollywood (Hindi)  Drama, Biography    Vidhu Vinod Chopra
# 1  Bollywood (Hindi)            Comedy  Hrishikesh Mukherjee
# 2  Kollywood (Tamil)      Crime, Drama   Nithilan Saminathan
# 3  Kollywood (Tamil)      Crime, Drama           Mani Ratnam
# 4     Bengali Cinema             Drama          Satyajit Ray
#
#   BoxOfficeCollection  UserReviews                        Awards  \
# 0         $138,288.00          945      23 wins & 32 nominations
# ...

# %%
top250_movies_india.loc['1995':'2000','YearOfRelease']
# Out:
# 200    2022
# Name: YearOfRelease, dtype: int64

# %%
plt.figure(figsize=(6,20))
plt.title("Average Arrival Delay for Spirit Airlines Flights, by Month")
sns.barplot(y=top250_movies_india.Genre, x=top250_movies_india['Rating'])
# plt.ylabel("Arrival delay (in minutes)")
# Out:
# <Axes: title={'center': 'Average Arrival Delay for Spirit Airlines Flights, by Month'}, xlabel='Rating', ylabel='Genre'>

# %%
plt.figure(figsize=(6,20))
plt.title("Average Arrival Delay for Spirit Airlines Flights, by Month")
sns.barplot(y=top250_movies_india['Streaming platform'], x=top250_movies_india['Rating'])
# plt.ylabel("Arrival delay (in minutes)")
# Out:
# <Axes: title={'center': 'Average Arrival Delay for Spirit Airlines Flights, by Month'}, xlabel='Rating', ylabel='Streaming platform'>

# %%
plt.figure(figsize=(6,30))
plt.title("User Reviews")
# sns.barplot(y=top250_movies_india.Genre, x=top250_movies_india['Rating'])
# plt.ylabel("Arrival delay (in minutes)")
top250_movies_india.plot(kind='scatter',y='Streaming platform',x='Year of release',title='Movie Released in streaming platforms from 1995-2024')
# Out:
# <Axes: title={'center': 'Movie Released in streaming platforms from 1995-2024'}, xlabel='Year of release', ylabel='Streaming platform'>

# %%
# plt.title("User Reviews from 1955 to 2024")
# sns.barplot(y=top250_movies_india.Genre, x=top250_movies_india['Rating'])
# plt.ylabel("Arrival delay (in minutes)")
top250_movies_india.plot(kind='scatter',y='User reviews',x='Year of release')
# Out:
# <Axes: xlabel='Year of release', ylabel='User reviews'>

# %%
plt.title("User Reviews from 1955 to 2024")
sns.barplot(x=top250_movies_india.Ratedby, y=top250_movies_india['Year of release'])
# plt.ylabel("Arrival delay (in minutes)")
# top250_movies_india.plot(kind='scatter',y='User reviews',x='Year of release')
sns.boxenplot(x=top250_movies_india.Ratedby, y=top250_movies_india['Year of release'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ankur\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year of release'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 2
#       1 plt.title("User Reviews from 1955 to 2024")
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# load the dataset
df = pd.read_csv('data/IMdB_India_Top250.csv')

# basic Information
print("Dataset Information:")
print(df.info())

print("\nFirst Few Rows:")
print(df.head())

# summary Statistics
print("\nSummary Statistics:")
print(df.describe(include='all'))
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MovieName            250 non-null    object
#  1   YearOfRelease        250 non-null    int64
#  2   WatchHour            250 non-null    object
#  3   Rating               250 non-null    float64
#  4   Ratedby              250 non-null    object
#  5   FilmIndustry         250 non-null    object
#  6   Genre                250 non-null    object
#  7   Director             250 non-null    object
#  8   BoxOfficeCollection  250 non-null    object
#  9   UserReviews          250 non-null    int64
#  10  Awards               250 non-null    object
#  11  Description          250 non-null    object
#  12  StreamingPlatform    250 non-null    object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 25.5+ KB
# None
#
# First Few Rows:
# ...

# %%
# convert Box Office Collection to numeric
df['Box office collection'] = df['Box office collection'].replace({'NIL': '0'}, regex=True)
df['Box office collection'] = df['Box office collection'].replace({'\$': ''}, regex=True)
df['Box office collection'] = df['Box office collection'].replace({',': ''}, regex=True)
df['Box office collection'] = pd.to_numeric(df['Box office collection'], errors='coerce')
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\ankur\AppData\Local\Temp\ipykernel_13604\85348893.py:3: SyntaxWarning: invalid escape sequence '\$'
#   df['Box office collection'] = df['Box office collection'].replace({'\$': ''}, regex=True)
# C:\Users\ankur\AppData\Local\Temp\ipykernel_13604\85348893.py:3: SyntaxWarning: invalid escape sequence '\$'
#   df['Box office collection'] = df['Box office collection'].replace({'\$': ''}, regex=True)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ankur\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# ...
